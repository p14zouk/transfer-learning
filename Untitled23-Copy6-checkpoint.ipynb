# %%
import tensorflow

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
vgg16_model = keras.applications.vgg16.VGG16()

# %%
vgg16_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
type(vgg16_model)
keras.engine.training.Model
# Out:
# keras.engine.training.Model

# %%
import keras.models
import numpy as np
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Lambda, Dense, Flatten
from keras.optimizers import Adam

import os
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image

# %%
model = Sequential()
for layer in vgg16_model.layers:
    model.add(layer)

# %%
for layer in model.layers:
    layer.trainable = False

# %%
model.add(Dense(3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# ...

# %%
model.compile(optimizer=Adam(learning_rate=.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import image
model.compile(optimizer=Adam(learning_rate=.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# LOADING FILES

# %%
train_datagen=ImageDataGenerator(preprocessing_function=preprocess_input) 

train_generator=train_datagen.flow_from_directory('C:\\Users\\Nick\\Trans5', 
                                                 target_size=(224,224),
                                                 color_mode='rgb',
                                                 batch_size=1,
                                                 class_mode='categorical',
                                                 shuffle=True)

# %%
import h5py
checkpoint_path = "C:\\Users\\Nick\\anaconda3\\envs\\tenf\\training1\\cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tensorflow.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %% [markdown]
# TRAIN

# %%
step_size_train=train_generator.n//train_generator.batch_size
model.fit_generator(generator=train_generator,
                   steps_per_epoch=step_size_train,
                   epochs=10,
                   callbacks=[cp_callback])
# Out:
# Epoch 1/10
# 480/480 [==============================] - 382s 796ms/step - loss: 1.0730 - accuracy: 0.8083
#
# Epoch 00001: saving model to C:\Users\Nick\anaconda3\envs\tenf\training1\cp.ckpt
# Epoch 2/10
# 480/480 [==============================] - 382s 795ms/step - loss: 1.0686 - accuracy: 0.7854
#
# Epoch 00002: saving model to C:\Users\Nick\anaconda3\envs\tenf\training1\cp.ckpt
# Epoch 3/10
# 480/480 [==============================] - 436s 909ms/step - loss: 1.0641 - accuracy: 0.8000
#
# Epoch 00003: saving model to C:\Users\Nick\anaconda3\envs\tenf\training1\cp.ckpt
# Epoch 4/10
# 480/480 [==============================] - 428s 892ms/step - loss: 1.0597 - accuracy: 0.8104
#
# Epoch 00004: saving model to C:\Users\Nick\anaconda3\envs\tenf\training1\cp.ckpt
# Epoch 5/10
# 480/480 [==============================] - 374s 780ms/step - loss: 1.0553 - accuracy: 0.8250
#
# Epoch 00005: saving model to C:\Users\Nick\anaconda3\envs\tenf\training1\cp.ckpt
# Epoch 6/10
# ...

# %%
model.load_weights(checkpoint_path)

# %%
from PIL import Image, ImageFile
import requests
import numpy as np
from io import BytesIO
from IPython.display import display, HTML


IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
IMAGE_CHANNELS = 3

images = [
    "https://ichef.bbci.co.uk/wwfeatures/live/976_549/images/live/p0/7z/n7/p07zn7p7.jpg",
    "https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/dog-puppy-on-garden-royalty-free-image-1586966191.jpg",
    "https://assets.petco.com/petco/image/upload/f_auto,q_auto/canary-2",
    "https://images-na.ssl-images-amazon.com/images/I/81qRGJSxQoL.png",
    "https://bostonglobe-prod.cdn.arcpublishing.com/resizer/lt4RBGP6QaKJ50_dE9RYwNjJXBA=/1440x0/arc-anglerfish-arc2-prod-bostonglobe.s3.amazonaws.com/public/6NJIVWVGRZEERA46BKCCS3UY2E.jpg",
    "https://2rdnmg1qbg403gumla1v9i2h-wpengine.netdna-ssl.com/wp-content/uploads/sites/3/2020/04/petCoronovirus-DG-042320-770x553-1-650x428.jpg"
    
]


def make_square(img):
    cols,rows = img.size
    
    if rows>cols:
        pad = (rows-cols)/2
        img = img.crop((pad,0,cols,cols))
    else:
        pad = (cols-rows)/2
        img = img.crop((0,pad,rows,rows))
    
    return img
        
for url in images:
    x = []
    ImageFile.LOAD_TRUNCATED_IMAGES = False
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img.load()
    img = img.resize((IMAGE_WIDTH,IMAGE_HEIGHT),Image.ANTIALIAS)
    
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    pred = model.predict(x)
    
    display("___________________________________________________________________________________________")
    display(img)
    print(np.argmax(pred,axis=1))
# Out:
# '___________________________________________________________________________________________'
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1BD81EF1E48>
# [2]
# '___________________________________________________________________________________________'
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1BD81EF1E48>
# [2]
# '___________________________________________________________________________________________'
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1BD81EF1E48>
# [0]
# '___________________________________________________________________________________________'
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1BD81EF1E48>
# [0]
# '___________________________________________________________________________________________'
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1BD81EF1E48>
# [1]
# '___________________________________________________________________________________________'
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1BD81EF1E48>
# ...
